# %%
# Name: Saman Yaghini
# Student ID: 100286511

import numpy as np
import math

rho_n = 0
tau_n = 0
mu_n = 0


#setup functions instead

def calc_rho_n(x):
    rho_n = 0
    for n in range(1,x+1):
        rho_n += (-1)**(n+1)/(2*n-1)
    rho_n *= 4
    return rho_n

def calc_tau_n(x):
    tau_n = 0
    for n in range(1, x+1):
        tau_n += 1/n**2
    tau_n *= 6
    tau_n = math.sqrt(tau_n)
    return tau_n

def calc_mu_n(x):
    mu_n = 0
    for n in range(1, x+1):
        mu_n += 1/n**4
    mu_n *= 90
    mu_n = mu_n**(1/4)
    return mu_n

# n = 10
rho_n = calc_rho_n(10)
print ('When n = 10, rho_n =      ' + '%0.11f' % rho_n)        
rho_n = 0

tau_n = calc_tau_n(10)
print ('When n = 10, tau_n =      ' + '%0.11f' % tau_n)
tau_n = 0

mu_n = calc_mu_n(10)
print ('When n = 10, mu_n =       ' + '%0.11f' % mu_n)
mu_n = 0

# n = 100
rho_n = calc_rho_n(100)
print ('When n = 100, rho_n =     ' + '%0.11f' % rho_n)        
rho_n = 0

tau_n = calc_tau_n(100)
print ('When n = 100, tau_n =     ' + '%0.11f' % tau_n)
tau_n = 0

mu_n = calc_mu_n(100)
print ('When n = 100, mu_n =      ' + '%0.11f' % mu_n)
mu_n = 0

# n = 1000
rho_n = calc_rho_n(1000)
print ('When n = 1000, rho_n =    ' + '%0.11f' % rho_n)        
rho_n = 0

tau_n = calc_tau_n(1000)
print ('When n = 1000, tau_n =    ' + '%0.11f' % tau_n)
tau_n = 0

mu_n = calc_mu_n(1000)
print ('When n = 1000, mu_n =     ' + '%0.11f' % mu_n)
mu_n = 0

# n = 10000
rho_n = calc_rho_n(10000)
print ('When n = 10000, rho_n =   ' + '%0.11f' % rho_n)        
rho_n = 0

tau_n = calc_tau_n(10000)
print ('When n = 10000, tau_n =   ' + '%0.11f' % tau_n)
tau_n = 0

mu_n = calc_mu_n(10000)
print ('When n = 10000, mu_n =    ' + '%0.11f' % mu_n)
mu_n = 0

# n = 100000
rho_n = calc_rho_n(100000)
print ('When n = 100000, rho_n =  ' + '%0.11f' % rho_n)        
rho_n = 0

tau_n = calc_tau_n(100000)
print ('When n = 100000, tau_n =  ' + '%0.11f' % tau_n)
tau_n = 0

mu_n = calc_mu_n(100000)
print ('When n = 100000, mu_n =   ' + '%0.11f' % mu_n)
mu_n = 0

# n = 1000000
rho_n = calc_rho_n(1000000)
print ('When n = 1000000, rho_n = ' + '%0.11f' % rho_n)        
rho_n = 0

tau_n = calc_tau_n(1000000)
print ('When n = 1000000, tau_n = ' + '%0.11f' % tau_n)
tau_n = 0

mu_n = calc_mu_n(1000000)
print ('When n = 1000000, mu_n =  ' + '%0.11f' % mu_n)
mu_n = 0
# Out:
# When n = 10, rho_n =      3.04183961893
# When n = 10, tau_n =      3.04936163598
# When n = 10, mu_n =       3.14138462247
# When n = 100, rho_n =     3.13159290356
# When n = 100, tau_n =     3.13207653181
# When n = 100, mu_n =      3.14159241531
# When n = 1000, rho_n =    3.14059265384
# When n = 1000, tau_n =    3.14063805621
# When n = 1000, mu_n =     3.14159265335
# When n = 10000, rho_n =   3.14149265359
# When n = 10000, tau_n =   3.14149716395
# When n = 10000, mu_n =    3.14159265359
# When n = 100000, rho_n =  3.14158265359
# When n = 100000, tau_n =  3.14158310433
# When n = 100000, mu_n =   3.14159265359
# When n = 1000000, rho_n = 3.14159165359
# When n = 1000000, tau_n = 3.14159169866
# When n = 1000000, mu_n =  3.14159265359
